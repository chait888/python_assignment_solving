# %%
s1="Hello world!"
s1.find("world!")
# Out:
# 6

# %%
s1[6:11]
# Out:
# 'world'

# %%
s1="python"
s1[1:5]
# Out:
# 'ytho'

# %%
s2="abcdefgh"
s2[2:6]
# Out:
# 'cdef'

# %%
s="programming"
s[-3:]
# Out:
# 'ing'

# %%
s="I love coding"
s[2:6]
# Out:
# 'love'

# %%
s="Good morning"
s[::-1]
# Out:
# 'gninrom dooG'

# %%
s="Hello ,how are you?"
s[7:14]
# Out:
# 'how are'

# %%
s="example"
s[1:6]
# Out:
# 'xampl'

# %%
long_word = "supercalifragilisticexpialidocious"

# %%
long_word[:11]
# Out:
# 'supercalifr'

# %%
s="abcdef"
s[
