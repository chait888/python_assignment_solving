# %%
a=int(input("Enter the number:"))
b=str(a)
b
# Out:
# Enter the number: 6
# '6'

# %%
x=str(input("Enter the number"))
y=int(x)
x+y
# Out:
# Enter the number 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 x=str(input("Enter the number"))
#       2 y=int(x)
# ----> 3 x+y
#
# TypeError: can only concatenate str (not "int") to str

# %%
a=float(input("Enter the number:"))
b=int(a)
b
# Out:
# Enter the number: 6.5
# 6

# %%
a=int(input("Enter the number:"))
b=int(input("Enter the number:"))
c=a//b
b=float(c)
b
# Out:
# Enter the number: 10
# Enter the number: 5
# 2.0

# %%
s1=1,2,5,6,8
l=list(s1)
l
# Out:
# [1, 2, 5, 6, 8]
